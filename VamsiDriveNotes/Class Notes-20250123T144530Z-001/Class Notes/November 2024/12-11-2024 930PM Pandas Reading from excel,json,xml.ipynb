# %%
import pandas as pd

# %%
dry_beans = pd.read_excel('c:/data/Dry_Bean_Dataset.xlsx')
dry_beans
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
df = pd.read_excel('c:/data/AdventureWorks2017.xlsx',sheet_name=["FactInternetSales"])
df['FactInternetSales']
# Out:
#        ProductKey  OrderDateKey  DueDateKey  ShipDateKey  CustomerKey  \
# 0             310      20101229    20110110     20110105        21768
# 1             310      20101229    20110110     20110105        21768
# 2             346      20101229    20110110     20110105        28389
# 3             346      20101229    20110110     20110105        25863
# 4             336      20101229    20110110     20110105        14501
# ...           ...           ...         ...          ...          ...
# 60394         485      20140128    20140209     20140204        15868
# 60395         225      20140128    20140209     20140204        15868
# 60396         485      20140128    20140209     20140204        18759
# 60397         486      20140128    20140209     20140204        18759
# 60398         225      20140128    20140209     20140204        18759
#
#        PromotionKey  CurrencyKey  SalesTerritoryKey SalesOrderNumber  \
# ...

# %%
df1 = pd.read_excel('c:/data/AdventureWorks2017.xlsx',sheet_name=None)

# %%
type(df1)
# Out:
# dict

# %%
df1.keys()
# Out:
# dict_keys(['DimProductCategory', 'DimProductSubcategory', 'DimDate', 'FactInternetSales', 'DimGeography', 'DimProduct'])

# %%
df_internetsales = df1['FactInternetSales']
df_internetsales
# Out:
#        ProductKey  OrderDateKey  DueDateKey  ShipDateKey  CustomerKey  \
# 0             310      20101229    20110110     20110105        21768
# 1             310      20101229    20110110     20110105        21768
# 2             346      20101229    20110110     20110105        28389
# 3             346      20101229    20110110     20110105        25863
# 4             336      20101229    20110110     20110105        14501
# ...           ...           ...         ...          ...          ...
# 60394         485      20140128    20140209     20140204        15868
# 60395         225      20140128    20140209     20140204        15868
# 60396         485      20140128    20140209     20140204        18759
# 60397         486      20140128    20140209     20140204        18759
# 60398         225      20140128    20140209     20140204        18759
#
#        PromotionKey  CurrencyKey  SalesTerritoryKey SalesOrderNumber  \
# ...

# %%
df_productcategory = df1['DimProductCategory']
df_productcategory
# Out:
#    ProductCategoryKey  ProductCategoryAlternateKey ProductCategoryName
# 0                   1                            1               Bikes
# 1                   2                            2          Components
# 2                   3                            3            Clothing
# 3                   4                            4         Accessories

# %%
cars_json = pd.read_json('c:/data/cars.json')
cars_json
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
cars_xml = pd.read_xml('c:/data/cars.xml')
cars_xml
# Out:
#     model  price  mileage   color
# 0     SEL  21992     7846  Silver
# 1     SEL  20995    10926    Gray
# 2     SEL  19995     7351  Silver
# 3     SEL  17809    11613    Gray
# 4      SE  17500     8367   White
# ..    ...    ...      ...     ...
# 145   SES   6200    95000  Silver
# 146    SE   5995    87003     Red
# 147    SE   5980    96841     Red
# 148    SE   4899   151479  Yellow
# 149    SE   3800   109259     Red
#
# [150 rows x 4 columns]
