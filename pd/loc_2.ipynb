# %%
import pandas as pd
df = pd.read_csv('DataSets/churn.csv',delimiter=',', header=0)
df.set_index(keys='gender',append=False, inplace=True)
df.loc['Male',['customerID','tenure']]
# Out:
#         customerID  tenure
# gender
# Male    5575-GNVDE      34
# Male    3668-QPYBK       2
# Male    7795-CFOCW      45
# Male    1452-KIOVK      22
# Male    6388-TABGU      62
# ...            ...     ...
# Male    9767-FFLEM      38
# Male    8456-QDAVC      19
# Male    6840-RESVB      24
# Male    8361-LTMKD       4
# Male    3186-AJIEK      66
#
# [3555 rows x 2 columns]

# %%
import pandas as pd
df = pd.read_csv('DataSets/churn.csv',delimiter=',', header=0)
df.set_index(keys='gender',append=False, inplace=True)
df.loc[:,'customerID':'tenure']
# Out:
#         customerID  SeniorCitizen Partner Dependents  tenure
# gender
# Female  7590-VHVEG              0     Yes         No       1
# Male    5575-GNVDE              0      No         No      34
# Male    3668-QPYBK              0      No         No       2
# Male    7795-CFOCW              0      No         No      45
# Female  9237-HQITU              0      No         No       2
# ...            ...            ...     ...        ...     ...
# Male    6840-RESVB              0     Yes        Yes      24
# Female  2234-XADUH              0     Yes        Yes      72
# Female  4801-JZAZL              0     Yes        Yes      11
# Male    8361-LTMKD              1     Yes         No       4
# Male    3186-AJIEK              0      No         No      66
#
# [7043 rows x 5 columns]

# %%
import pandas as pd
df = pd.read_csv('DataSets/churn.csv',delimiter=',', header=0)
df.set_index(keys='gender',append=False, inplace=True)
df.loc['Male','customerID':'tenure':2]
# Out:
#         customerID Partner  tenure
# gender
# Male    5575-GNVDE      No      34
# Male    3668-QPYBK      No       2
# Male    7795-CFOCW      No      45
# Male    1452-KIOVK      No      22
# Male    6388-TABGU      No      62
# ...            ...     ...     ...
# Male    9767-FFLEM      No      38
# Male    8456-QDAVC      No      19
# Male    6840-RESVB     Yes      24
# Male    8361-LTMKD     Yes       4
# Male    3186-AJIEK      No      66
#
# [3555 rows x 3 columns]

# %%
import pandas as pd
df = pd.read_csv('DataSets/churn.csv',delimiter=',', header=0)
df.set_index(keys='gender',append=False, inplace=True)
df.loc[['Male','Female'],:]
# Out:
#         customerID  SeniorCitizen Partner Dependents  tenure PhoneService  \
# gender
# Male    5575-GNVDE              0      No         No      34          Yes
# Male    3668-QPYBK              0      No         No       2          Yes
# Male    7795-CFOCW              0      No         No      45           No
# Male    1452-KIOVK              0      No        Yes      22          Yes
# Male    6388-TABGU              0      No        Yes      62          Yes
# ...            ...            ...     ...        ...     ...          ...
# Female  0639-TSIQW              0      No         No      67          Yes
# Female  7750-EYXWZ              0      No         No      12           No
# Female  2569-WGERO              0      No         No      72          Yes
# Female  2234-XADUH              0     Yes        Yes      72          Yes
# Female  4801-JZAZL              0     Yes        Yes      11           No
#
#            MultipleLines InternetService       OnlineSecurity  \
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('DataSets/fruits.csv',sep=',',header=0)
df = df.sample(20)
df
# Out:
#               color  sphericity  weight   label
# 40   Reddish yellow       0.778     174   Apple
# 47              Red       0.845     154   Apple
# 28            Green       0.870     101  Orange
# 0            Orange       0.947     120  Orange
# 13            Green       0.849     119  Orange
# 20  Greenish yellow       0.838     101  Orange
# 31            Green       0.711     170   Apple
# 21  Greenish yellow       0.824     149  Orange
# 33            Green       0.831     152   Apple
# 26            Green       0.809     108  Orange
# 34            Green       0.721     172   Apple
# 53   Reddish yellow       0.815     152   Apple
# 42              Red       0.776     172   Apple
# 39            Green       0.727     160   Apple
# 4            Orange       0.943     124  Orange
# 3            Orange       0.916     123  Orange
# 5            Orange       0.911     130  Orange
# 8            Orange       0.914     132  Orange
# 36            Green       0.775     173   Apple
# ...

# %%
df.iloc[0:10] # iloc
# Out:
#               color  sphericity  weight   label
# 40   Reddish yellow       0.778     174   Apple
# 47              Red       0.845     154   Apple
# 28            Green       0.870     101  Orange
# 0            Orange       0.947     120  Orange
# 13            Green       0.849     119  Orange
# 20  Greenish yellow       0.838     101  Orange
# 31            Green       0.711     170   Apple
# 21  Greenish yellow       0.824     149  Orange
# 33            Green       0.831     152   Apple
# 26            Green       0.809     108  Orange

# %%
df.loc[39:38]
# Out:
#      color  sphericity  weight   label
# 39   Green       0.727     160   Apple
# 4   Orange       0.943     124  Orange
# 3   Orange       0.916     123  Orange
# 5   Orange       0.911     130  Orange
# 8   Orange       0.914     132  Orange
# 36   Green       0.775     173   Apple
# 38   Green       0.733     184   Apple

# %%
import pandas as pd

df = pd.read_csv('DataSets/usedcars.csv', index_col=['model','color'])
df.head(100)
df.loc[[('SES', 'White'), ('SE', 'Blue')], :]
# Out:
#              year  price  mileage transmission
# model color
# SES   White  2003   7900    96000         AUTO
# SE    Blue   2010  15500    29338         AUTO
#       Blue   2010  14480    24855         AUTO
#       Blue   2010  13950    37185         AUTO
#       Blue   2009  13845    36713         AUTO
#       Blue   2010  13350    16573         AUTO
#       Blue   2009  12998    34846         AUTO
#       Blue   2009  12995    42325         AUTO
#       Blue   2009  11999    36124         AUTO
#       Blue   2007   9651    63296         AUTO
