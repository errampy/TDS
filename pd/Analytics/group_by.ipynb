# %%
import pandas as pd

df = pd.read_csv('../DataSets/usedcars.csv')
df.groupby(by=['color','model']).describe()
# Out:
#               year                         ...   mileage
#              count         mean       std  ...       50%        75%       max
# color  model                               ...
# Black  SE     19.0  2009.578947  0.837708  ...   34419.0   37361.00  106171.0
#        SEL     4.0  2010.250000  0.500000  ...   28978.0   34911.75   40539.0
#        SES    12.0  2008.416667  1.831955  ...   41596.5   60299.75  119720.0
# Blue   SE      9.0  2009.222222  0.971825  ...   36124.0   37185.00   63296.0
#        SEL     3.0  2010.333333  1.154701  ...   20019.0   23706.00   27393.0
#        SES     5.0  2008.400000  2.190890  ...   36323.0   39211.00   69415.0
# Gold   SE      1.0  2009.000000       NaN  ...   40180.0   40180.00   40180.0
# Gray   SE      7.0  2009.142857  0.690066  ...   41342.0   46481.50   53902.0
#        SEL     5.0  2010.000000  1.000000  ...   29501.0   35574.00   78264.0
#        SES     4.0  2008.500000  3.000000  ...   31592.5   52634.25  101130.0
# ...
