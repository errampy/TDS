# %% [markdown]
# # Concadination
# 1. _Appending the n dataframe into single dataframe, there should be not any dependacy on other datafame_
# 2. _We can append rows wise and as well as column too, if wannt to append rows wise then axis=0 else axis=1_
# 3. _merge is something like joins concepts in SQL, to perform merge operation into pandas then needs relationship between two dataframe but for concadination no need any realtionshiip._
# 4.

# %%
import pandas as pd

# %%
df1 = pd.read_csv('../DataSets/Hotels/bangalore.csv')
df1
# Out:
#                                             Hotel Name  Rating  \
# 0                                   The Park Bangalore     3.9
# 1    Keys Select by Lemon Tree Hotels, Whitefield, ...     4.0
# 2              ITC Windsor - A Luxury Collection Hotel     4.4
# 3             Lemon Tree Premier Ulsoor Lake Bangalore     4.0
# 4    Keys Select by Lemon Tree Hotels, Hosur Road, ...     4.0
# ..                                                 ...     ...
# 96                 Shravanthi Sarovar Portico JP Nagar     3.6
# 97                       Vivanta Bengaluru, Whitefield     4.3
# 98                          Melange Astris\r\nLike a 3     4.1
# 99                                   Octave Church Inn     3.5
# 100                         Mastiff Infantry Bengaluru     4.0
#
#     Rating Description  Reviews  Star Rating              Location  \
# 0            Very Good   4187.0          5.0                Ulsoor
# 1            Very Good   2201.0          4.0           Brookefield
# ...

# %%
df2 = pd.read_csv('../DataSets/Hotels/chennai.csv')
df2
# Out:
#                                          Hotel Name  Rating  \
# 0                           Taj Club House, Chennai     4.3
# 1                                  The Park Chennai     3.7
# 2        Taj Fisherman's Cove Resort & Spa, Chennai     4.3
# 3                                      Hotel Savera     4.0
# 4                 Ibis Chennai OMR - An Accor Brand     4.1
# ..                                              ...     ...
# 96          Pebbles Serviced Apartments\r\nLike a 3     4.2
# 97   Mercure Chennai Sriperumbudur - An Accor Brand     4.2
# 98                                  ZAITH RESIDENCY     3.4
# 99                             Mount Kailash Suites     4.0
# 100                The Mount City near US Consulate     3.6
#
#     Rating Description  Reviews  Star Rating           Location  \
# 0            Excellent     2000          5.0         Royapettah
# 1            Very Good     8366          5.0  Near US Consulate
# ...

# %%
df3 = pd.read_csv('../DataSets/Hotels/delhi.csv')
df3
# Out:
#                                             Hotel Name  Rating  \
# 0        Country Inn and Suites by Radisson, Sahibabad     4.2
# 1                     Radisson Blu Kaushambi Delhi NCR     4.0
# 2                                            The Ashok     3.8
# 3                 Pride Plaza Hotel Aerocity New Delhi     4.0
# 4    Golden Tulip Vasundhara Hotel & Suites, Delhi NCR     3.9
# ..                                                 ...     ...
# 96                Caspia Hotel New Delhi Shalimar Bagh     3.4
# 97                  Park Inn by Radisson, Lajpat Nagar     4.1
# 98                                Jukaso Inn Down Town     3.6
# 99                                  Hotel LA New Delhi     3.6
# 100                   Kelvish Hotel Near Delhi Airport     3.9
#
#     Rating Description  Reviews  Star Rating          Location  \
# 0            Very Good    15697          5.0     In Ghaziabad
# 1            Very Good     1826          5.0     In Ghaziabad
# ...

# %%
df4 = pd.read_csv('../DataSets/Hotels/hyderabad.csv')
df4
# Out:
#                                     Hotel Name  Rating Rating Description  \
# 0                Radisson Hyderabad Hitec City     3.7          Very Good
# 1                           The Park Hyderabad     3.7          Very Good
# 2      ITC Kohenur - A Luxury Collection Hotel     4.3          Excellent
# 3   Fairfield by Marriott Hyderabad Gachibowli     3.9          Very Good
# 4                     Radisson Blu Plaza Hotel     4.1          Very Good
# ..                                         ...     ...                ...
# 70                                 Taj Tristar     3.9          Very Good
# 71                     Minerva Grand - Banjara     4.0          Very Good
# 72                          Sheraton Hyderabad     4.3          Excellent
# 73    ITC Kakatiya - A Luxury Collection Hotel     4.2          Very Good
# 74                  Bikanervala Boutique Hotel     4.1          Very Good
#
#     Reviews  Star Rating       Location Nearest Landmark Distance to Landmark  \
# ...

# %%
df5= pd.read_csv('../DataSets/Hotels/kolkata.csv')
df5
# Out:
#                                  Hotel Name  Rating Rating Description  \
# 0                          The Park Kolkata     3.9          Very Good
# 1                 Zone By The Park, Kolkata     3.8          Very Good
# 2                 JW Marriott Hotel Kolkata     4.4          Excellent
# 3    ibis Kolkata Rajarhat - An Accor Brand     3.9          Very Good
# 4           The Lalit Great Eastern Kolkata     4.2          Very Good
# ..                                      ...     ...                ...
# 96                Hotel Gateway Continental     3.8          Very Good
# 97                           Hotel Air View     4.0          Very Good
# 98                       Hotel Casa Fortuna     3.9          Very Good
# 99                            Middleton Inn     3.5          Very Good
# 100              Hotel Sawood International     3.6          Very Good
#
#      Reviews  Star Rating          Location  \
# 0       7647          5.0  New Market Area
# ...

# %%
df6= pd.read_csv('../DataSets/Hotels/mumbai.csv')
df6
# Out:
#                                         Hotel Name  Rating Rating Description  \
# 0               The Orchid Hotel Mumbai Vile Parle     4.0          Very Good
# 1                             Trident Bandra Kurla     4.6          Excellent
# 2    ITC Grand Central - A Luxury Collection Hotel     4.5          Excellent
# 3              IRA By Orchid Mumbai ( VITS Mumbai)     3.9          Very Good
# 4                            Trident Nariman Point     4.6          Excellent
# ..                                             ...     ...                ...
# 96        Blossom Dormitory ( For Male and Female)     3.6          Very Good
# 97                            Comfort Inn Heritage     3.9          Very Good
# 98                          Hotel Planet Residency     3.8          Very Good
# 99                            Hotel Kohinoor Elite     4.1          Very Good
# 100                        Residency Hotel Andheri     4.0          Very Good
#
# ...

# %%
# Row Wise Concadication
# ========================
rows_wise_con = pd.concat(objs=[df1,df2, df3,df4],axis=0)
rows_wise_con
# Out:
#                                            Hotel Name  Rating  \
# 0                                  The Park Bangalore     3.9
# 1   Keys Select by Lemon Tree Hotels, Whitefield, ...     4.0
# 2             ITC Windsor - A Luxury Collection Hotel     4.4
# 3            Lemon Tree Premier Ulsoor Lake Bangalore     4.0
# 4   Keys Select by Lemon Tree Hotels, Hosur Road, ...     4.0
# ..                                                ...     ...
# 70                                        Taj Tristar     3.9
# 71                            Minerva Grand - Banjara     4.0
# 72                                 Sheraton Hyderabad     4.3
# 73           ITC Kakatiya - A Luxury Collection Hotel     4.2
# 74                         Bikanervala Boutique Hotel     4.1
#
#    Rating Description  Reviews  Star Rating              Location  \
# 0           Very Good   4187.0          5.0                Ulsoor
# 1           Very Good   2201.0          4.0           Brookefield
# ...

# %%
# Column Wise Concadination
# ===========================
colums_wise_con = pd.concat(objs=[df1,df2, df3,df4],axis=1)
colums_wise_con
# Out:
#                                             Hotel Name  Rating  \
# 0                                   The Park Bangalore     3.9
# 1    Keys Select by Lemon Tree Hotels, Whitefield, ...     4.0
# 2              ITC Windsor - A Luxury Collection Hotel     4.4
# 3             Lemon Tree Premier Ulsoor Lake Bangalore     4.0
# 4    Keys Select by Lemon Tree Hotels, Hosur Road, ...     4.0
# ..                                                 ...     ...
# 96                 Shravanthi Sarovar Portico JP Nagar     3.6
# 97                       Vivanta Bengaluru, Whitefield     4.3
# 98                          Melange Astris\r\nLike a 3     4.1
# 99                                   Octave Church Inn     3.5
# 100                         Mastiff Infantry Bengaluru     4.0
#
#     Rating Description  Reviews  Star Rating              Location  \
# 0            Very Good   4187.0          5.0                Ulsoor
# 1            Very Good   2201.0          4.0           Brookefield
# ...
