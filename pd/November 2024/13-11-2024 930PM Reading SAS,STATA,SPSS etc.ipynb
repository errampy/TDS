# %%
import pandas as pd

# %%
employees = pd.read_fwf('e:/data/sample_fwf.csv',header=None,widths=[4,6,5,2],
                       names=['empno','ename','salary','deptno'])
employees
# Out:
#    empno   ename  salary  deptno
# 0   1001  abcdef   25000      20
# 1   1002  wxyzab   50000      30
# 2   1003  efghij   30000      10

# %%
airlines = pd.read_sas('e:/data/airline.sas7bdat')
airlines
# Out:
#       YEAR          Y      W       R      L      K
# 0   1948.0   1.214000  0.243  0.1454  1.415  0.612
# 1   1949.0   1.354000  0.260  0.2181  1.384  0.559
# 2   1950.0   1.569000  0.278  0.3157  1.388  0.573
# 3   1951.0   1.948000  0.297  0.3940  1.550  0.564
# 4   1952.0   2.265000  0.310  0.3559  1.802  0.574
# 5   1953.0   2.731000  0.322  0.3593  1.926  0.711
# 6   1954.0   3.025000  0.335  0.4025  1.964  0.776
# 7   1955.0   3.562000  0.350  0.3961  2.116  0.827
# 8   1956.0   3.979000  0.361  0.3822  2.435  0.800
# 9   1957.0   4.420000  0.379  0.3045  2.707  0.921
# 10  1958.0   4.563000  0.391  0.3284  2.706  1.067
# 11  1959.0   5.385000  0.426  0.3856  2.846  1.083
# 12  1960.0   5.554000  0.441  0.3193  3.089  1.481
# 13  1961.0   5.465000  0.460  0.3079  3.122  1.736
# 14  1962.0   5.825000  0.485  0.3783  3.184  1.926
# 15  1963.0   6.876000  0.506  0.4180  3.263  2.041
# 16  1964.0   7.823000  0.538  0.5163  3.412  1.997
# ...

# %%
import polars as ps

# %%
cars = ps.read_csv('e:/data/usedcars.csv')
type(cars)
# Out:
# polars.dataframe.frame.DataFrame

# %%
cars
# Out:
# shape: (150, 6)
# ┌──────┬───────┬───────┬─────────┬────────┬──────────────┐
# │ year ┆ model ┆ price ┆ mileage ┆ color  ┆ transmission │
# │ ---  ┆ ---   ┆ ---   ┆ ---     ┆ ---    ┆ ---          │
# │ i64  ┆ str   ┆ i64   ┆ i64     ┆ str    ┆ str          │
# ╞══════╪═══════╪═══════╪═════════╪════════╪══════════════╡
# │ 2011 ┆ SEL   ┆ 21992 ┆ 7413    ┆ Yellow ┆ AUTO         │
# │ 2011 ┆ SEL   ┆ 20995 ┆ 10926   ┆ Gray   ┆ AUTO         │
# │ 2011 ┆ SEL   ┆ 19995 ┆ 7351    ┆ Silver ┆ AUTO         │
# │ 2011 ┆ SEL   ┆ 17809 ┆ 11613   ┆ Gray   ┆ AUTO         │
# │ 2012 ┆ SE    ┆ 17500 ┆ 8367    ┆ White  ┆ AUTO         │
# │ …    ┆ …     ┆ …     ┆ …       ┆ …      ┆ …            │
# │ 2006 ┆ SES   ┆ 6200  ┆ 95000   ┆ Silver ┆ AUTO         │
# │ 2002 ┆ SE    ┆ 5995  ┆ 87003   ┆ Red    ┆ AUTO         │
# │ 2000 ┆ SE    ┆ 5980  ┆ 96841   ┆ Red    ┆ AUTO         │
# │ 2001 ┆ SE    ┆ 4899  ┆ 151479  ┆ Yellow ┆ AUTO         │
# │ 2000 ┆ SE    ┆ 3800  ┆ 109259  ┆ Red    ┆ AUTO         │
# ...

# %%
df_stata = pd.read_stata('e:/data/airline.dta')
df_stata
# Out:
#     year          y      w       r      l      k
# 0   1948   1.214000  0.243  0.1454  1.415  0.612
# 1   1949   1.354000  0.260  0.2181  1.384  0.559
# 2   1950   1.569000  0.278  0.3157  1.388  0.573
# 3   1951   1.948000  0.297  0.3940  1.550  0.564
# 4   1952   2.265000  0.310  0.3559  1.802  0.574
# 5   1953   2.731000  0.322  0.3593  1.926  0.711
# 6   1954   3.025000  0.335  0.4025  1.964  0.776
# 7   1955   3.562000  0.350  0.3961  2.116  0.827
# 8   1956   3.979000  0.361  0.3822  2.435  0.800
# 9   1957   4.420000  0.379  0.3045  2.707  0.921
# 10  1958   4.563000  0.391  0.3284  2.706  1.067
# 11  1959   5.385000  0.426  0.3856  2.846  1.083
# 12  1960   5.554000  0.441  0.3193  3.089  1.481
# 13  1961   5.465000  0.460  0.3079  3.122  1.736
# 14  1962   5.825000  0.485  0.3783  3.184  1.926
# 15  1963   6.876000  0.506  0.4180  3.263  2.041
# 16  1964   7.823000  0.538  0.5163  3.412  1.997
# 17  1965   9.120000  0.564  0.5879  3.623  2.257
# ...

# %%
loan_df = pd.read_spss('e:/data/loan_roc.sav')
loan_df
# Out:
#      age                     education  year_emp  income  debt_income  \
# 0   47.0  Did not complete high school      22.0    81.0          5.5
# 1   40.0  Did not complete high school      22.0    95.0          3.6
# 2   35.0  Did not complete high school      16.0    36.0          3.4
# 3   43.0  Did not complete high school      16.0    89.0          0.4
# 4   47.0  Did not complete high school      26.0   100.0         12.8
# ..   ...                           ...       ...     ...          ...
# 95  28.0                  Some college       6.0    47.0         19.8
# 96  34.0  Did not complete high school      12.0    68.0         25.1
# 97  23.0            High school degree       0.0    17.0         27.7
# 98  35.0            High school degree      11.0    62.0         32.4
# 99  33.0  Did not complete high school      14.0    72.0         41.3
#
#     cred_debt  other_debt Loan   Logistc PGR_1 Dis_1    Dis1_1   Discrim
# ...

# %%
pd.read_
