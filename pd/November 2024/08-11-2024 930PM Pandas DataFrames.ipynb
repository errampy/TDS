# %%
import pandas as pd

# %%
cars = pd.read_csv('e:/data/usedcars.csv',delimiter=',')
cars
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
cars = pd.read_csv('e:/data/usedcars.csv',usecols=["model",'price','mileage'])
cars
# Out:
#     model  price  mileage
# 0     SEL  21992     7413
# 1     SEL  20995    10926
# 2     SEL  19995     7351
# 3     SEL  17809    11613
# 4      SE  17500     8367
# ..    ...    ...      ...
# 145   SES   6200    95000
# 146    SE   5995    87003
# 147    SE   5980    96841
# 148    SE   4899   151479
# 149    SE   3800   109259
#
# [150 rows x 3 columns]

# %%
credit = pd.read_csv('e:/data/credit.csv',
                     usecols=['purpose','amount','months_loan_duration','age'])
credit
# Out:
#      months_loan_duration     purpose  amount  age
# 0                       6    radio/tv    1169   67
# 1                      48    radio/tv    5951   22
# 2                      12   education    2096   49
# 3                      42   furniture    7882   45
# 4                      24   car (new)    4870   53
# ..                    ...         ...     ...  ...
# 995                    12   furniture    1736   31
# 996                    30  car (used)    3857   40
# 997                    12    radio/tv     804   38
# 998                    45    radio/tv    1845   23
# 999                    45  car (used)    4576   27
#
# [1000 rows x 4 columns]

# %%
air_quality = pd.read_csv('e:/data/AirQuality.csv',sep=';',decimal=",")
air_quality
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
cars = pd.read_csv('e:/data/usedcars.csv',header=1)
cars
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
iris = pd.read_csv('e:/data/IRIS.csv',
                   header=None,
                  names=['sepal_length','sepal_width','petal_length','petal_width',"species"])
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
