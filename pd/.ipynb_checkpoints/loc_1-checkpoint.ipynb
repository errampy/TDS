# %%
import pandas as pd
df = pd.read_excel('DataSets/Dry_Bean_Dataset.xlsx')
df2 = df.set_index(keys=['Area','Eccentricity'],drop=True,append=False,inplace=True)

# %%
import pandas as pd
s = pd.Series(data=[i for i in range(10)], index= [i for i in range(10,20)])
# type(s),len(s), dir(s), sorted(s)
dict(s)
s.describe()
# Out:
# count    10.00000
# mean      4.50000
# std       3.02765
# min       0.00000
# 25%       2.25000
# 50%       4.50000
# 75%       6.75000
# max       9.00000
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv('DataSets/cars/City_Master.csv', header=0, usecols=[0,2], nrows=10,skiprows=[1,2,3,5],)
df
# Out:
#   City_Code State_Code
# 0      CT04       ST24
# 1      CT06       ST22
# 2      CT07       ST13
# 3      CT08       ST29
# 4      CT09       ST34
# 5      CT10       ST12
# 6      CT11       ST07
# 7      CT12       ST28
# 8      CT13       ST04
# 9      CT14       ST07

# %%
# Set index
import pandas as pd
df = pd.read_csv('DataSets/census.csv', sep=',')
df.set_index(keys=['YEAR','DEC','MAY'], drop=True, append=False,inplace=False)
# Out:
#                          JAN     FEB     MAR     APR     JUN     JUL     AUG  \
# YEAR DEC      MAY
# 1992 155504.0 149015  146913  147270  146831  148082  149821  150809  151064
# 1993 168101.0 160624  157525  156292  154774  158996  160171  162832  162491
# 1994 181492.0 172340  167504  169652  172775  173099  174307  174801  177289
# 1995 190809.0 183543  182423  179472  180996  181702  186088  185470  186814
# 1996 201191.0 196210  189167  192269  193993  194712  196127  196229  196215
# 1997 209379.0 201676  202414  204273  204965  203372  204666  207049  207643
# 1998 223226.0 214619  209684  209532  210792  213623  216324  214853  213669
# 1999 245498.0 231238  224020  226240  227407  228978  231926  233933  236589
# 2000 250603.0 246225  243483  247133  249847  245789  248178  247184  247601
# 2001 256552.0 255262  252736  252730  250346  254759  254020  253015  254570
# 2002 265802.0 257616  256376  257677  257060  261320  259815  262811  264975
# ...

# %%
# Reset index
import pandas as pd
df = pd.read_csv('DataSets/census.csv', sep=',')
df = df.set_index(keys=['YEAR','JUN','DEC'], )
df.index

df.reset_index(level='YEAR', drop=True, inplace=True)
# Out:
#                     JAN     FEB     MAR     APR     MAY     JUL     AUG  \
# JUN    DEC
# 149821 155504.0  146913  147270  146831  148082  149015  150809  151064
# 160171 168101.0  157525  156292  154774  158996  160624  162832  162491
# 174307 181492.0  167504  169652  172775  173099  172340  174801  177289
# 186088 190809.0  182423  179472  180996  181702  183543  185470  186814
# 196127 201191.0  189167  192269  193993  194712  196210  196229  196215
# 204666 209379.0  202414  204273  204965  203372  201676  207049  207643
# 216324 223226.0  209684  209532  210792  213623  214619  214853  213669
# 231926 245498.0  224020  226240  227407  228978  231238  233933  236589
# 248178 250603.0  243483  247133  249847  245789  246225  247184  247601
# 254020 256552.0  252736  252730  250346  254759  255262  253015  254570
# 259815 265802.0  256376  257677  257060  261320  257616  262811  264975
# 270432 277567.0  267276  263199  267842  267240  267347  273393  277901
# ...

# %%
# Filter
import pandas as pd
df = pd.read_csv('DataSets/insurance.csv', sep=',')
df[df.gender=='male']
# Out:
#       age gender     bmi  children smoker     region      charges
# 1      18   male  33.770         1     no  southeast   1725.55230
# 2      28   male  33.000         3     no  southeast   4449.46200
# 3      33   male  22.705         0     no  northwest  21984.47061
# 4      32   male  28.880         0     no  northwest   3866.85520
# 8      37   male  29.830         2     no  northeast   6406.41070
# ...   ...    ...     ...       ...    ...        ...          ...
# 1324   31   male  25.935         1     no  northwest   4239.89265
# 1325   61   male  33.535         0     no  northeast  13143.33665
# 1327   51   male  30.030         1     no  southeast   9377.90470
# 1329   52   male  38.600         2     no  southwest  10325.20600
# 1333   50   male  30.970         3     no  northwest  10600.54830
#
# [673 rows x 7 columns]

# %%
# Filter
import pandas as pd
df = pd.read_csv('DataSets/insurance.csv', sep=',')
df[(df.gender=='female')&(df.smoker=='yes')]
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 19     30  female  35.300         0    yes  southwest  36837.46700
# 23     34  female  31.920         1    yes  northeast  37701.87680
# 58     53  female  22.880         1    yes  southeast  23244.79020
# ...   ...     ...     ...       ...    ...        ...          ...
# 1308   25  female  30.200         0    yes  southwest  33900.65300
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1314   30  female  23.655         3    yes  northwest  18765.87545
# 1323   42  female  40.370         2    yes  southeast  43896.37630
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [116 rows x 7 columns]

# %%
# Filter
import pandas as pd
df = pd.read_csv('DataSets/insurance.csv', sep=',')
df.query("gender=='female' and smoker =='yes'")
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 19     30  female  35.300         0    yes  southwest  36837.46700
# 23     34  female  31.920         1    yes  northeast  37701.87680
# 58     53  female  22.880         1    yes  southeast  23244.79020
# ...   ...     ...     ...       ...    ...        ...          ...
# 1308   25  female  30.200         0    yes  southwest  33900.65300
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1314   30  female  23.655         3    yes  northwest  18765.87545
# 1323   42  female  40.370         2    yes  southeast  43896.37630
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [116 rows x 7 columns]
